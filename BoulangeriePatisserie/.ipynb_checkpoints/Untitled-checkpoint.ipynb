# %%
import pandas as pd

# %%
df = pd.read_csv("valeurs_mensuelles.csv",sep=";")
old= df.columns

# %%
df.columns = ["a","b","c"]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["b"][2:])

# %%
old
# Out:
# Index([u'Libellé',
#        u'Indice brut de la production industrielle (base 100 en 2015) - Fabrication de produits de boulangerie-pâtisserie et de pâtes alimentaires (NAF rév. 2, niveau groupe, poste 10.7)',
#        u'Codes'],
#       dtype='object')
